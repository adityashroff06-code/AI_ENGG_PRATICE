# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Sai\anaconda3\envs\nlp_pratice_env\python.exe

# %%
libs = [
    "nltk",
    "spacy",
    "gensim",
    "sklearn",
    "transformers",
    "torch",
    "tensorflow",
    "sentence_transformers",
    "textblob"
]

status = {}

for lib in libs:
    try:
        __import__(lib)
        status[lib] = "✅ Installed"
    except ImportError:
        status[lib] = "❌ Not installed"

status
# Out:
# {'nltk': '✅ Installed',
#  'spacy': '✅ Installed',
#  'gensim': '✅ Installed',
#  'sklearn': '✅ Installed',
#  'transformers': '✅ Installed',
#  'torch': '✅ Installed',
#  'tensorflow': '❌ Not installed',
#  'sentence_transformers': '❌ Not installed',
#  'textblob': '✅ Installed'}

# %%
import nltk, spacy, sklearn

print("NLTK:", nltk.__version__)
print("spaCy:", spacy.__version__)
print("sklearn:", sklearn.__version__)
# Out:
# NLTK: 3.9.1
# spaCy: 3.8.3
# sklearn: 1.6.0

# %%
import sys
# !{sys.executable} -m pip list
# Out:
# Package                   Version
# ------------------------- ------------
# annotated-types           0.7.0
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    4.1.0
# blis                      1.3.3
# brotlicffi                1.2.0.0
# catalogue                 2.0.10
# certifi                   2026.1.4
# cffi                      2.0.0
# chardet                   5.2.0
# charset-normalizer        3.4.4
# click                     8.3.1
# cloudpathlib              0.23.0
# colorama                  0.4.6
# comm                      0.2.3
# confection                0.1.5
# contourpy                 1.3.3
# cycler                    0.12.1
# cymem                     2.0.13
# ...

# %%
#LOWERCASE

# %%
sentence = "Her Cat's Name is Luna"

# %%
lower_sentence = sentence.lower()

# %%
print(lower_sentence)
# Out:
# her cat's name is luna

# %%
sentence_list = ['AAAAAAAAAA  BBBBBBBB CCCCCCCC', 'BBBBBBBBB MMMMMMMM', 'ZZZZZZZZZ']

# %%
lower_sentence_list = [x.lower() for x in sentence_list]

# %%
print(lower_sentence_list)
# Out:
# ['aaaaaaaaaa  bbbbbbbb cccccccc', 'bbbbbbbbb mmmmmmmm', 'zzzzzzzzz']

# %%
#NLTK LIBRARY DOWNLOAD AND EXPERIMENTATION

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sai\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
en_stopwords = stopwords.words('english')

# %%
print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
sentence = "it was too far to go to the shop and he did not want her to talk"

# %%
sentence_no_stopwords = ' '.join([word for word in sentence.split() if word not in en_stopwords])

# %%
print(sentence_no_stopwords)
# Out:
# far go shop want talk

# %%
en_stopwords.remove("did")
en_stopwords.remove("not")

# %%
en_stopwords.append("go")

# %%
sentence_no_stopwords_custom = ' '.join([word for word in sentence.split() if word not in en_stopwords])

# %%
print(sentence_no_stopwords_custom)
# Out:
# far shop did not want talk

# %%
#REGEX - lets u describe a rule

# %%
import re

# %%
my_folder = "C\desktop\notes"
print (my_folder)
# Out:
# C\desktop
# otes

# %%
my_folder = r"C\desktop\notes"
print (my_folder)
# Out:
# C\desktop\notes

# %%
result_search = re.search("pattern", r"string to contain a pattern")

# %%
print(result_search)
# Out:
# <re.Match object; span=(20, 27), match='pattern'>

# %%
string = r"sara was able to help me find the items I needed quickly"

# %%
new_string = re.sub("sara","sarah",string)
print(new_string)
# Out:
# sarah was able to help me find the items I needed quickly

# %%
# write a "?" (after the optional letter) to keep one specific letter of a string as optional

# %%
customer_reviews = ['sam was a great help to me in the store', 
 'the cashier was very rude to me, I think her name was eleanor', 
 'amazing work from sadeen!', 
 'sarah was able to help me find the items i needed quickly', 
 'lucy is such a great addition to the team', 
 'great service from sara she found me what i wanted']

# %%
sarahs_reviews = []

# %%
pattern_to_find = r"sarah?"

# %%
for string in customer_reviews:
    if (re.search(pattern_to_find,string)):
        sarahs_reviews.append(string)

# %%
print(sarahs_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
a_reviews = []
pattern_to_find = r"^a"

# %%
for string in customer_reviews:
    if(re.search(pattern_to_find,string)):
        a_reviews.append(string)

# %%
print(a_reviews)
# Out:
# ['amazing work from sadeen!']

# %%
#"^Char" - start of the string and "char$" - end of the string

# %%
#| - works like an or

# %%
needwant_reviews = []

# %%
pattern_to_find = r"(need|want)ed"

# %%
for string in customer_reviews:
    if(re.search(pattern_to_find,string)):
        needwant_reviews.append(string)

# %%
print(needwant_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
#PUNCTUATIONS = r"[^\w\s]"

# %%
#TOKENIZATION

# %%
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Sai\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
sentences = "Her cat's name is Luna, Her dog's name is Max"

# %%
sent_tokenize(sentences)
# Out:
# ["Her cat's name is Luna, Her dog's name is Max"]

# %%
sentence = "her cat's name is luna"
word_tokenize(sentence)
# Out:
# ['her', 'cat', "'s", 'name', 'is', 'luna']

# %%
sentence_2 = "Her cat's name is Luna and her dog's name is Thukaniyo"
word_tokenize(sentence_2)
# Out:
# ['Her',
#  'cat',
#  "'s",
#  'name',
#  'is',
#  'Luna',
#  'and',
#  'her',
#  'dog',
#  "'s",
#  'name',
#  'is',
#  'Thukaniyo']

# %%
#STEMMING - reduces complexity by reducing unique words from the dataset by standardizing the text

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
connect_tokens = ['connecting']

# %%
connect_tokens = ['connecting', 'connected',  'connectivity', 'connect', 'connects']

# %%
for t in connect_tokens:
    print(t, ":", ps.stem(t))
# Out:
# connecting : connect
# connected : connect
# connectivity : connect
# connect : connect
# connects : connect

# %%
#LEMMATIZATION

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Sai\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
for t in connect_tokens:
    print(t,": ", lemmatizer.lemmatize(t))
# Out:
# connecting :  connecting
# connected :  connected
# connectivity :  connectivity
# connect :  connect
# connects :  connects

# %%
print('Hello World')
# Out:
# Hello World

# %%
#N-Grams - PRATICE

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
tokens = ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']
print(tokens)
# Out:
# ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']

# %%
unigrams = (pd.Series(nltk.ngrams(tokens,1)).value_counts())
print(unigrams[:10])
# Out:
# (to,)          7
# (of,)          6
# (the,)         4
# (in,)          4
# (learning,)    3
# (and,)         3
# (from,)        2
# (more,)        2
# (is,)          2
# (that,)        2
# Name: count, dtype: int64

# %%
unigrams[:10].sort_values().plot.barh(color= "lightsalmon", width= .9, figsize(12,8))
plt.title("10 Most frequently Occuring Unigrams")
# Out:
#   Cell In[14], line 1
#     unigrams[:10].sort_values().plot.barh(color= "lightsalmon", width= .9, figsize(12,8))
#                                                                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
unigrams[:10].sort_values().plot.bar(figsize=(12,8), color="lightsalmon", width=0.9)
plt.title("10 Most frequently Occurring Unigrams")
# Out:
# Text(0.5, 1.0, '10 Most frequently Occurring Unigrams')

# %%
bigrams = (pd.Series(nltk.ngrams(tokens, 2)).value_counts()) 
print(bigrams)
# Out:
# (that, were)             2
# (the, rise)              1
# (increasingly, being)    1
# (ai, is)                 1
# (result, ai)             1
#                         ..
# (tasks, that)            1
# (complex, tasks)         1
# (perform, complex)       1
# (to, perform)            1
# (to, come)               1
# Name: count, Length: 105, dtype: int64

# %%
bigrams[0:10].sort_values().plot.barh(color='skyblue', width=.9, figsize=(12, 8))
plt.title('10 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')

# %% [markdown]
# #We convert the text in pandas series bceause it can be treated as structured data and can be used for sorting,counting and visualization
